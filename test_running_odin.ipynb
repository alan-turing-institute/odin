# %%
import odin
import vne

# %%
from odin.model import Odin_model
# Out:
# Traceback (most recent call last):
#
#   File "/usr/local/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3418, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   File "<ipython-input-4-6238774acf1a>", line 1, in <module>
#     from odin.model import Odin_model
#
#   File "/Users/bcostagomes/Documents/Code/odin/odin/model.py", line 47
#     self.best_model_path = './models/shapes/nms'+str(nms)+'_bestmodel.pt'
#                                                                          ^
# TabError: inconsistent use of tabs and spaces in indentation

# %%
model = Odin_model()
# Out:
# params set

# %%
model.set_optimizer()

# %%
# Out:
# [Parameter containing:
#  tensor([[[[ 0.0114]],
#
#           [[ 0.0001]],
#
#           [[ 0.0019]],
#
#           ...,
#
#           [[-0.0199]],
#
#           [[-0.0102]],
#
#           [[ 0.0031]]],
#
#
#          [[[ 0.0172]],
#
#           [[-0.0014]],
#
#           [[-0.0356]],
#
#           ...,
#
#           [[-0.0047]],
#
#           [[ 0.0374]],
#
#           [[-0.0224]]],
#
#
#          [[[ 0.0391]],
#
#           [[-0.0338]],
#
#           [[ 0.0032]],
#
#           ...,
#
#           [[-0.0028]],
#
#           [[ 0.0112]],
#
#           [[-0.0106]]],
#
#
#          ...,
#
#
#          [[[-0.0061]],
#
#           [[ 0.0021]],
#
#           [[-0.0153]],
#
#           ...,
#
#           [[-0.0208]],
#
#           [[-0.0130]],
#
#           [[ 0.0020]]],
#
#
#          [[[-0.0210]],
#
#           [[-0.0363]],
#
#           [[-0.0094]],
#
#           ...,
#
#           [[ 0.0125]],
#
#           [[ 0.0288]],
#
#           [[ 0.0226]]],
#
#
#          [[[-0.0241]],
#
# ...
